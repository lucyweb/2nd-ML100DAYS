# %% [markdown]
# # 作業 : (Kaggle)鐵達尼生存預測精簡版
# https://www.kaggle.com/c/titanic

# %% [markdown]
# # [作業目標]
# - 試著不依賴說明, 只依照下列程式碼回答下列問題, 初步理解什麼是"特徵工程"的區塊

# %% [markdown]
# # [作業重點]
# - 試著不依賴註解, 以之前所學, 回答下列問題

# %% [markdown]
# # 作業1
# * 下列A~E五個程式區塊中，哪一塊是特徵工程?
# Respond Ans C;  B段只是整理DataFrame
#
# # 作業2
# * 對照程式區塊 B 與 C 的結果，請問那些欄位屬於"類別型欄位"? (回答欄位英文名稱即可)
# My Ans: Pclass、Sex、Ticket、Cabin、Embarked;
#
# Respond Ans: Name, Sex, Ticket, Cabin, Embarked 等五個欄位
#
# 註 : 像是 Pclass 這樣的欄位, 雖然就意義上而言是類別型欄位, 但因為裡面都是數值,
# 因此 Python 讀取時會先將其判定為數值欄位, 希望同學了解語言判定與人為理解上的落差,
# 因為 Python 不須宣告物件型別, 都是自動判定, 這點雖然方便, 卻也是初學者常常遇到的困難所在
#
# # 作業3
# * 續上題，請問哪個欄位是"目標值"? Survived

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
from google.colab import files
uploaded = files.upload()

df_train = pd.read_csv( 'titanic_train.csv')
# Out:
#      <input type="file" id="files-cff29436-77fe-405e-85bd-eee084628e5e" name="files[]" multiple disabled />
#      <output id="result-cff29436-77fe-405e-85bd-eee084628e5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic_train.csv to titanic_train (1).csv

# %%
from google.colab import files
uploaded = files.upload()

df_test = pd.read_csv( 'titanic_test.csv')
df_train.shape
# Out:
#      <input type="file" id="files-4c7128e7-0b38-43e5-ae58-ee3b402b5985" name="files[]" multiple disabled />
#      <output id="result-4c7128e7-0b38-43e5-ae58-ee3b402b5985">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic_test.csv to titanic_test.csv
# (891, 12)

# %%
# 程式區塊 A
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

data_path = 'data/'
df_train = pd.read_csv(data_path + 'titanic_train.csv')
df_test = pd.read_csv(data_path + 'titanic_test.csv')
df_train.shape

# %%
# 程式區塊 B
train_Y = df_train['Survived']
ids = df_test['PassengerId']
df_train = df_train.drop(['PassengerId', 'Survived'] , axis=1)
df_test = df_test.drop(['PassengerId'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
# 程式區塊 C
LEncoder = LabelEncoder()
MMEncoder = MinMaxScaler()
for c in df.columns:
    df[c] = df[c].fillna(-1)
    if df[c].dtype == 'object':
        df[c] = LEncoder.fit_transform(list(df[c].values))
    df[c] = MMEncoder.fit_transform(df[c].values.reshape(-1, 1))
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
#    Pclass      Name  Sex       Age  SibSp  Parch    Ticket      Fare  \
# 0     1.0  0.118683  1.0  0.283951  0.125    0.0  0.775862  0.016072
# 1     0.0  0.218989  0.0  0.481481  0.125    0.0  0.879310  0.140813
# 2     1.0  0.400459  0.0  0.333333  0.000    0.0  0.984914  0.017387
# 3     0.0  0.323124  0.0  0.444444  0.125    0.0  0.070043  0.105390
# 4     1.0  0.016845  1.0  0.444444  0.000    0.0  0.699353  0.017630
#
#       Cabin  Embarked
# 0  0.000000  1.000000
# 1  0.575269  0.333333
# 2  0.000000  1.000000
# 3  0.381720  1.000000
# 4  0.000000  1.000000

# %%
# 程式區塊 D
train_num = train_Y.shape[0]
train_X = df[:train_num]
test_X = df[train_num:]

from sklearn.linear_model import LogisticRegression
estimator = LogisticRegression()
estimator.fit(train_X, train_Y)
pred = estimator.predict(test_X)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# 程式區塊 E
sub = pd.DataFrame({'PassengerId': ids, 'Survived': pred})
sub.to_csv('titanic_baseline.csv', index=False)

# %%
# !ls
# Out:
# sample_data  titanic_baseline.csv  titanic_test.csv  titanic_train.csv

# %%
# !rm 'titanic_train (1).csv'

# %%
sub1 = pd.read_csv( 'titanic_baseline.csv')

# %%
sub1.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
