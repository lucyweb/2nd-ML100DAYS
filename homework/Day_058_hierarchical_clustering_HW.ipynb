# %% [markdown]
# # Hierarchical clustering with 2D toy datasets

# %% [markdown]
# # [作業目標]
# - 將階層式聚類套用在 2D 樣板資料上, 來觀察幾種不同參數的結果有何不同

# %% [markdown]
# # [作業重點]
# - 以幾種 2D 樣板資料, 觀察階層式聚類在 "linkage參數" 有所不同時, 分群的效果如何變化 (In[4], Out[4])# [作業重點]
# - 以幾種 2D 樣板資料, 觀察階層式聚類在 "linkage參數" 有所不同時, 分群的效果如何變化 (In[4], Out[4])

# %%
# 載入套件
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# %%
# 設定 2D 樣板資料
n_samples = 1500
random_state = 100

# 生成 雙半月 資料點; make_moons: make two interleaving half circles
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)  #X, y

# 生成 緊密三群 資料點; make_blobs用blobs承接
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8) #X, y

# 生成 2維均勻分布 資料點
no_structure = np.random.rand(n_samples, 2), None #X, no y

# %%
# 設定群集與繪圖參數
plt.figure(figsize=(10, 8))
plot_num = 1
default_base = {'n_neighbors': 10, 'n_clusters': 3}
datasets = [(noisy_moons, {'n_clusters': 2}), (blobs, {}), (no_structure, {})]

# %% [markdown]
# # 作業
# * 試著完成剩下三種 2D 樣板資料的繪圖, 並觀察有何不同

# %%
# 執行各種樣板資料的繪圖迴圈
for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # 複製參數與標準化
    params = default_base.copy()
    params.update(algo_params)    
    X, y = dataset
    X = StandardScaler().fit_transform(X)

    # 設定三種不同參數的 Hierarchical clustering
    ward = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="ward")
    complete = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="complete")
    average = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="average")
    clustering_algorithms = (
        ('Average', average),
        ('Complete', complete),
        ('Ward', ward))

    # 繪製三種圖形
    for name, algorithm in clustering_algorithms:
        # t0 / t1 : 紀錄時間差
        t0 = time.time()
        algorithm.fit(X)
        t1 = time.time()
        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(np.int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(.99, .01, ('%.2fs' % (t1 - t0)).lstrip('0'), transform=plt.gca().transAxes, size=15,
                 horizontalalignment='right')
        plot_num += 1
plt.show()

# %% [markdown]
# *  雙半月 : 三者效果 都不佳
# *  緊密三群 : 三者效果 都還不錯
# *  2維均勻分布 : 三者效果 都還不錯

# %%
lis = ['cat','dog','bear']

for i, e in enumerate(lis):
  print(i+1, e)
# Out:
# 1 cat
# 2 dog
# 3 bear

# %%
from sklearn.datasets import make_blobs

x1, y1 = make_blobs(n_samples=200, n_features=2, centers=3) #另外一種寫法
# 绘制样本显示
plt.scatter(x1[:, 0], x1[:, 1], c=y1)
plt.show()

# %%
no_str = np.random.rand(10, 2), None
sets = [(no_structure, {})]
for i_dataset, (dataset, algo_params) in enumerate(sets):
  i, j = dataset
  para = algo_params
  print(j)
# Out:
# None

# %%
no_str
# Out:
# (array([[0.91704137, 0.23156048],
#         [0.49920155, 0.58398241],
#         [0.5590412 , 0.98557218],
#         [0.7849714 , 0.45916701],
#         [0.09955936, 0.36055202],
#         [0.2602665 , 0.91615139],
#         [0.30512485, 0.50663652],
#         [0.75457232, 0.05238617],
#         [0.94786124, 0.55627569],
#         [0.53816285, 0.35553491]]), None)
