# %% [markdown]
# # 作業目標:
#     運用 Keras 模組建構CNN, 了解 CNN 的架構

# %% [markdown]
# # 作業重點
# (1)嘗試比對 Dense 與 layers.Conv2D 架構NN 的差異
#
# (2) 有沒有Pooling layer, 對於參數量的差異
#
# 注意: input_shape 請勿修改

# %%
#導入相關模組
import keras
from keras import layers
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense

#確認keras 版本
print(keras.__version__)
# Out:
# Using TensorFlow backend.
# 2.2.4

# %%
'''
model = Sequential([
    Dense(xxx),
    Activation(xxx),
    Dense(xxx),
    Activation(xxx),
])
'''

model = Sequential([
    Dense(32, input_shape=(784,)),
    Activation('relu'),
    Dense(32),
    Activation('relu'),
    Dense(100),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 07:24:47.805706 140213764728704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0730 07:24:47.829813 140213764728704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0730 07:24:47.832941 140213764728704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                25120
# ...

# %% [markdown]
# # layers.Conv2D 模型, 用作比對
#
# ![CNN_Model.png](attachment:CNN_Model.png)

# %%
'''
#建立一個序列模型
model = models.Sequential()
#建立兩個卷績層, 32 個內核, 內核大小 3x3, 
#輸入影像大小 28x28x1

#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))
'''
#建立一個序列模型
model = models.Sequential()

#輸入影像大小 28x28x1; Conv2D(dense, filter, input)
#新增一池化層, 採用maxpooling
model.add(layers.Conv2D(32, (3, 3), input_shape=(28, 28, 1))) 
model.add(MaxPooling2D(2,2))

#建立第二個卷績層, 池化層,
model.add(layers.Conv2D(32, (3, 3)))
model.add(MaxPooling2D(2,2)) 
 
#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))

model.summary()
# Out:
# W0730 07:24:52.227884 140213764728704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5, 5, 100)         3300
# ...

# %%
#建立一個序列模型
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), input_shape=(28, 28, 1))) #輸入影像大小 28x28x1
#model.add(MaxPooling2D(2,2)) #新增一池化層, 採用maxpooling

 
#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立第二個卷績層, 池化層,
model.add(layers.Conv2D(32, (3, 3)))
model.add(MaxPooling2D(2,2)) 

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# dense_7 (Dense)              (None, 26, 26, 100)       3300
# _________________________________________________________________
# activation_7 (Activation)    (None, 26, 26, 100)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        28832
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dense_8 (Dense)              (None, 12, 12, 10)        330
# _________________________________________________________________
# activation_8 (Activation)    (None, 12, 12, 10)        0
# ...
# Total params: 32,782
# ...
